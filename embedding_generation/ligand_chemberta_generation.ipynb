# %%
# extract_smiles_from_sdf.py
from rdkit import Chem
import pandas as pd
from pathlib import Path

sdf_dir = Path("/data1/home/jw1017/GLAS_Dock/Data/ready_data/ligand_sdf_files")  # folder containing .sdf
records = []
for sdf_path in sdf_dir.glob("*.sdf"):
    suppl = Chem.SDMolSupplier(str(sdf_path), sanitize=True)
    mol = next((m for m in suppl if m is not None), None)
    if mol:
        smiles = Chem.MolToSmiles(mol)
        ligand_id = sdf_path.stem
        records.append({"ligand_id": ligand_id, "smiles": smiles})

df = pd.DataFrame(records)
df.to_csv("ligand_smiles.csv", index=False)
print(f"Extracted {len(df)} ligands.")
# Out:
# Extracted 5623 ligands.

# %%
# chemberta_embed.py
import torch
from transformers import AutoTokenizer, AutoModel
import pandas as pd
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
tok = AutoTokenizer.from_pretrained("/data1/home/jw1017/GLAS_Dock/Data/embedding_models/chemberta_77M_MLM", local_files_only=True)
model = AutoModel.from_pretrained("/data1/home/jw1017/GLAS_Dock/Data/embedding_models/chemberta_77M_MLM", local_files_only=True).to(device).eval()

df = pd.read_csv("ligand_smiles.csv")
embeddings, ids = [], []

with torch.no_grad():
    for i, row in tqdm(df.iterrows(), total=len(df)):
        smi = row["smiles"]
        enc = tok(smi, return_tensors="pt", truncation=True, padding=True).to(device)
        out = model(**enc).last_hidden_state.mean(1)  # mean-pool tokens
        embeddings.append(out.cpu())
        ids.append('_'.join(row["ligand_id"].split('_')[:-1]))

emb = torch.cat(embeddings, dim=0)
torch.save({"ligand_ids": ids, "embeddings": emb}, "ligand_chemberta.pt")
print(f"Saved {len(ids)} embeddings, dim={emb.shape[1]}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at /data1/home/jw1017/GLAS_Dock/Data/embedding_models/chemberta_77M_MLM and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 5623/5623 [00:15<00:00, 357.82it/s]
# Saved 5623 embeddings, dim=384

# %%
graph = torch.load("ligand_chemberta.pt")

# %%
graph
# Out:
# {'ligand_ids': ['5uio_LG3_B_201',
#   '6flu_DTK_B_401',
#   '4jhh_H35_A_201',
#   '7V17_OQO',
#   '7KLX_WOV',
#   '4nir_6DH_A_308',
#   '5nh9_XLS_D_504',
#   '8GEZ_ZMB',
#   '8AO6_ANP',
#   '6y4f_GLU_A_202',
#   '8QBC_GEE',
#   '7RGX_D9J',
#   '4mig_G3F_B_802',
#   '7SLZ_L6U',
#   '5eo7_SFU_B_403',
#   '5tch_MLI_C_301',
#   '7WN5_JGL',
#   '7A9E_R4W',
#   '7HG3_X0S',
#   '4ma8_Z80_C_301',
#   '4p8c_Y22_B_502',
#   '2pvy_ACP_A_802',
#   '4a8p_PAO_C_1340',
#   '8FO5_Y4Q',
#   '2uyv_TLA_A_1277',
#   '8CSD_C5P',
#   '8BSA_DLY',
#   '7F10_0BJ',
#   '2zut_A2G_B_4002',
#   '5c8w_PCG_D_302',
#   '2dv0_ZST_A_600',
#   '1LPZ_CMB',
#   '7F1G_0QQ',
#   '7BCH_UR4',
#   '1z6k_OAA_A_274',
#   '7N4Q_YD7',
#   '2cjz_PTR_A_1537',
#   '5je1_TOF_B_302',
#   '7V11_OTL',
#   '6o04_DNA_D_603',
#   '6rgg_K3Q_B_401',
#   '8V4G_CDP',
#   '7UR3_N6M',
#   '1T46_STI',
#   '2pin_LEG_A_501',
#   '4al9_GLA_C_1123',
#   '4x36_CHT_A_410',
#   '8BIN_QUF',
#   '7SCP_8S6',
#   '5eo7_SFU_C_403',
#   '7V12_ORF',
#   '2r4j_13P_A_1968',
#   '4nkw_PLO_A_601',
#   '5SGV_KI8',
#   '7FDT_4I1',
#   '7O0N_CDP',
#   '1lzz_IHG_A_830',
#   '5bkd_RCF_B_503',
#   '7ZYS_KNR',
#   '5o3f_9HT_A_501',
#   '6cut_FEJ_C_401',
#   '7FDU_4I6',
#   '5z54_0HZ_D_303',
#   '5i9m_69K_B_302',
#   '5di7_5CQ_B_601',
#   '1dpm_EBP_B_903',
#   '5edh_5MF_B_803',
#   '8WTQ_KUO',
#   '4h9g_14J_A_512',
#   '7GZV_A1AK4',
#   '1zb6_GST_A_502',
#   '8GFD_UL6',
#   '4bz6_SHH_C_700',
#   '6rgg_K3Q_A_401',
#   '8JQP_DHB',
#   '5ud0_13P_B_405',
#   '1t87_CAM_B_2422',
#   '8AIJ_M9I',
#   '1pke_2FD_C_448',
#   '4d0z_BBK_A_1581',
#   '7HGE_A1A3P',
#   '7LE5_A61',
#   '7B56_ANP',
#   '7MGY_ZD1',
#   '7LE4_DJR',
#   '2qx4_ML1_A_233',
#   '8HQQ_GAL',
#   '1oxp_IK2_A_411',
#   '5ita_6DC_A_801',
#   '1e8m_P0H_A_724',
#   '9F53_K3A',
#   '7HOC_WKY',
#   '4zu3_4SD_B_302',
#   '8BOI_QJI',
#   '7Q8Z_9IS',
#   '1m7p_G3H_B_6401',
#   '5uo5_M4R_A_803',
#   '5SGV_IZ6',
#   '7GNL_R7F',
#   '4bz6_SHH_B_700',
#   '1luq_BTN_B_5200',
#   '7XEF_D0I',
#   '2zwt_CAM_A_422',
#   '1o68_KIV_B_275',
#   '5faj_DCS_C_401',
#   '2qd4_CHD_A_803',
#   '6jz4_EVA_B_701',
#   '7LTY_YD7',
#   '7NGY_U9W',
#   '1a59_CIT_A_379',
#   '7CUO_PHB',
#   '2eb5_OXL_D_2004',
#   '7V1B_SAM',
#   '1v3v_5OP_B_2360',
#   '1itw_ICT_A_743',
#   '6pvi_OZ7_A_501',
#   '5del_ORO_A_602',
#   '5fiu_Y3J_A_1299',
#   '4ur9_BK9_A_1717',
#   '7B8K_T9Z',
#   '5a02_GOL_E_1341',
#   '6mnh_JVD_A_301',
#   '5x2m_GLN_D_951',
#   '2y2f_YI1_A_1469',
#   '4ndn_PPK_C_404',
#   '1f5f_DHT_A_253',
#   '2qgw_EES_B_1',
#   '7HGB_X0S',
#   '5fc5_PC_A_516',
#   '6f6a_CU5_A_301',
#   '4evq_PHB_B_402',
#   '5ybq_AKG_B_302',
#   '6krs_CIT_G_301',
#   '2iht_TPP_B_600',
#   '6k92_GT0_A_802',
#   '6n0z_DP6_B_401',
#   '5SMG_LPU',
#   '7RGZ_59O',
#   '5j61_A3G_C_501',
#   '5xmq_PLG_C_501',
#   '5fay_CHT_A_908',
#   '5tde_FLC_A_501',
#   '7G04_WXZ',
#   '5wgr_PM7_A_712',
#   '1h5r_THM_B_1293',
#   '7LDZ_K2D',
#   '7Q6W_95O',
#   '8V73_YHW',
#   '6m92_J8V_A_601',
#   '6flu_DTK_A_406',
#   '2fzb_TOL_A_800',
#   '2qvr_FDP_A_333',
#   '5yfj_RUB_A_401',
#   '1eyw_TEN_A_403',
#   '1R55_097',
#   '5je1_TOF_A_302',
#   '7H0B_A1ANI',
#   '6vei_9UO_B_502',
#   '3vnj_PSJ_B_301',
#   '6r4j_GLU_A_704',
#   '6XCT_478',
#   '1rf2_BV4_H_108',
#   '6mwl_K5G_B_301',
#   '4ejh_0QA_E_502',
#   '9GBE_AWJ',
#   '4cjw_CBJ_A_1216',
#   '1h5r_THM_C_1292',
#   '6mae_JBA_A_301',
#   '4hey_4MZ_A_308',
#   '7ORW_7WA',
#   '2htu_BCZ_A_801',
#   '8E5M_UKR',
#   '7bp1_CAQ_C_401',
#   '7RXO_88O',
#   '4itu_1HS_A_302',
#   '7T1H_E66',
#   '5ybq_8T0_B_303',
#   '5n5k_HAE_A_306',
#   '8VQ4_A1AC4',
#   '3wwc_BUA_A_403',
#   '8CLU_V0F',
#   '5vuu_9OJ_B_803',
#   '1XM6_5RM',
#   '4rii_TYD_A_401',
#   '8U94_ANP',
#   '6mry_FLC_I_102',
#   '1nuw_F6P_A_2336',
#   '6qot_6SD_A_301',
#   '7HGA_UWS',
#   '6cdy_EY1_B_501',
#   '7Q8Y_9IS',
#   '7BC9_EJW',
#   '4kux_FPS_D_704',
#   '1u1g_BBB_A_3300',
#   '6sjs_THH_B_901',
#   '6qaw_HVE_A_402',
#   '5nj0_8YW_A_301',
#   '6r7w_CIT_A_406',
#   '7V3S_5I9',
#   '1vkf_CIT_A_501',
#   '9MIU_A1L2V',
#   '5h24_LQG_A_501',
#   '8U2R_AMP',
#   '8V74_YHN',
#   '6flu_DTK_B_405',
#   '7FDX_X90',
#   '5v7y_AKG_B_302',
#   '5gwt_SIN_A_302',
#   '3u3o_3QV_A_296',
#   '1h82_GZZ_B_590',
#   '5jdv_EVF_B_302',
#   '4gcq_0JM_B_401',
#   '1z11_8MO_B_501',
#   '7RH1_D9J',
#   '8QC4_TXR',
#   '4hrq_AZG_B_201',
#   '9F2I_A1H88',
#   '8BAK_Q8U',
#   '5z9b_AX7_A_304',
#   '7LB3_XXS',
#   '4mig_G3F_D_802',
#   '7FU9_YTU',
#   '7XH6_JHL',
#   '7RPZ_6IC',
#   '8GFD_ZHE',
#   '7AVI_S2Q',
#   '5mzj_TEP_A_2401',
#   '3te7_TE7_A_1',
#   '7XVU_ZMR',
#   '1P2Y_NCT',
#   '7HGA_ZQD',
#   '8PST_N9F',
#   '1T40_ID5',
#   '7Q5O_37T',
#   '5yb7_ORN_C_603',
#   '7PJK_A1HZ2',
#   '5xoi_SIN_A_401',
#   '7H00_A1AK7',
#   '8JAB_U0X',
#   '7PUU_84O',
#   '7XQZ_FPF',
#   '4dta_ADN_A_401',
#   '6f77_PLP_D_600',
#   '1x09_IPE_A_902',
#   '1qmh_CIT_A_401',
#   '7P1F_KFN',
#   '7HGE_ZQD',
#   '7ZB3_IVG',
#   '1w78_PD8_A_1421',
#   '6rgr_RM4_A_403',
#   '6ZK5_IMH',
#   '4zbc_FRU_B_408',
#   '8W8L_W1Q',
#   '5tix_OQR_B_302',
#   '4du7_DP6_A_401',
#   '8QK2_VN6',
#   '1tf8_TRP_A_911',
#   '7NGG_UBN',
#   '5mot_HBD_A_401',
#   '7OLI_8HG',
#   '7T1G_E66',
#   '4zvv_GN0_D_403',
#   '5hfa_FP1_A_607',
#   '1w1a_NDG_2_1261',
#   '7V0Z_OQ6',
#   '5nh9_XLS_B_503',
#   '5r28_RDJ_A_401',
#   '1d7a_AIR_C_400',
#   '5k2c_ZMA_A_1201',
#   '7MLP_ZJ4',
#   '4cmk_FQW_D_1270',
#   '5oo4_URI_A_201',
#   '5kcp_PFB_B_379',
#   '6qo4_97T_B_301',
#   '7V13_ORU',
#   '2iyq_SKM_A_201',
#   '5lwy_OLB_A_406',
#   '8DHG_T78',
#   '4r08_URI_B_901',
#   '6ZAK_ACV',
#   '6flu_DTK_A_402',
#   '7B4X_SWT',
#   '6rgg_K3Q_A_402',
#   '5SJV_IYW',
#   '7YBA_IO9',
#   '6hl7_CP_A_401',
#   '7N7B_T3F',
#   '6l7v_3PO_A_302',
#   '6ooi_PGA_F_301',
#   '8OYZ_W6T',
#   '4mol_2FG_B_802',
#   '2o7d_DHC_H_701',
#   '4itu_1HS_B_302',
#   '6tgi_N8Z_A_508',
#   '7UJ4_OQ4',
#   '4xz9_G3P_B_302',
#   '1tc2_7HP_A_800',
#   '7DYQ_HR0',
#   '4zb5_GLC_A_403',
#   '6gxk_FFW_B_402',
#   '8UPI_SET',
#   '7FVZ_KL3',
#   '5a86_D7E_A_1433',
#   '5ihe_D5M_A_701',
#   '1h48_C5P_A_203',
#   '5hpu_IPH_A_101',
#   '7B8M_UR4',
#   '7HG1_EJQ',
#   '4ixw_IXW_A_302',
#   '4m72_M72_A_402',
#   '4z1d_PEP_B_300',
#   '6dyt_F0G_A_503',
#   '1r4s_MUA_A_800',
#   '1kya_XYD_D_814',
#   '8OUA_W26',
#   '4cx6_Q16_B_800',
#   '5zi4_OAA_B_401',
#   '4ekr_0R0_B_203',
#   '6fw0_E92_B_602',
#   '8I7S_6CI',
#   '7KC5_BJZ',
#   '3qfx_CP6_A_602',
#   '1YWR_LI9',
#   '8AN6_BTN',
#   '8S1X_BB2',
#   '7FW7_GFS',
#   '5SGW_WP3',
#   '6f77_PLP_A_600',
#   '5urz_BOG_B_201',
#   '1d7a_AIR_D_450',
#   '5la1_XYP_A_601',
#   '5igs_GMP_A_403',
#   '5SGW_K9F',
#   '8I6B_ORO',
#   '7B0E_C2E',
#   '8WL9_RIP',
#   '7H02_A1AK7',
#   '4al9_GLA_D_1123',
#   '7GCJ_LDX',
#   '7XRL_FWK',
#   '8SLG_G5A',
#   '8QHG_V8I',
#   '4e7v_CRS_1_101',
#   '4zo7_GLC_A_806',
#   '8BRX_B3M',
#   '7HG3_TU6',
#   '4cdt_M48_A_801',
#   '8AUB_O8I',
#   '7Y8C_IJV',
#   '4gnp_PEP_A_703',
#   '6lit_2OH_B_501',
#   '7HGB_ZQD',
#   '7FVW_IZ7',
#   '6jws_PT1_A_801',
#   '6hmw_FUL_B_204',
#   '8V6W_YJQ',
#   '5SM7_WKA',
#   '6lx5_C5F_B_502',
#   '5g44_SWX_A_1511',
#   '2pir_DHT_A_931',
#   '8BPL_CP',
#   '5hc0_NPO_A_402',
#   '7NGJ_UAW',
#   '7H01_A1ALS',
#   '8S04_A1H4I',
#   '8CZL_GSM',
#   '5uim_TYD_B_403',
#   '2e56_MYR_A_601',
#   '5j61_A3G_H_501',
#   '5agl_CCW_B_800',
#   '4mju_27S_A_501',
#   '4ghf_4NC_A_402',
#   '4k5g_Q13_A_803',
#   '6vmz_R3P_C_404',
#   '7FT9_4MB',
#   '4dwv_PFB_B_378',
#   '8SIV_UUF',
#   '3zcm_PX3_A_1214',
#   '8PT0_AN2',
#   '7EGO_OCA',
#   '5i9m_69K_C_302',
#   '7FW1_KL3',
#   '7ZCC_OGA',
#   '1toq_AMG_A_501',
#   '7N4Q_UQX',
#   '7HG7_X0S',
#   '5SKN_IK0',
#   '4clr_FDB_D_1270',
#   '6ZAE_ACV',
#   '2nu7_COA_B_1325',
#   '3wsg_CIT_D_302',
#   '1ns4_BGC_A_1400',
#   '1rum_BEZ_H_1601',
#   '8BOD_WT3',
#   '6jws_PT1_B_801',
#   '1jyx_IPT_C_2001',
#   '6mry_FLC_K_101',
#   '7V14_OQO',
#   '5eo7_SFU_B_401',
#   '5aew_BNL_C_462',
#   '8S98_ZRU',
#   '1amq_PMP_A_413',
#   '1thc_FL9_A_130',
#   '1nmm_NAG_D_527',
#   '7RH1_59O',
#   '1d6u_PEA_A_2003',
#   '8DHF_T6L',
#   '8AGQ_M5O',
#   '6l86_LMR_B_302',
#   '1cgk_NAR_A_390',
#   '6toj_NQQ_A_201',
#   '2b3f_GAL_D_3313',
#   '7JGW_V9S',
#   '6qor_JBK_B_301',
#   '7LZK_5JC',
#   '7NGG_UAW',
#   '4p8c_2J3_A_504',
#   '7GL3_SQ5',
#   '4a9j_TYL_B_1187',
#   '2fc0_DGP_A_239',
#   '5fe1_12Q_A_901',
#   '1ac4_TMT_A_296',
#   '3rsc_TYD_B_397',
#   '1v5y_4HC_B_1201',
#   '4fm6_TYR_C_259',
#   '7HG3_VZP',
#   '7V0Z_ORU',
#   '2qcx_PF1_A_300',
#   '6YR2_T1C',
#   '5j5i_6GM_G_302',
#   '5hss_64Z_A_402',
#   '1y5x_E89_A_500',
#   '4zbc_FRU_A_409',
#   '8RGK_GOQ',
#   '8DL4_SKX',
#   '1jho_RMB_A_990',
#   '7BMI_U4B',
#   '8JMZ_UKI',
#   '1rnd_DGP_A_126',
#   '7T1G_E5B',
#   '3sli_SKD_A_760',
#   '7SUF_BVI',
#   '5vut_9OG_A_803',
#   '5a86_D7E_B_1432',
#   '8AOP_7SE',
#   '3wug_XYP_C_2',
#   '4bvh_OCZ_A_1393',
#   '1y5x_E89_D_1500',
#   '8B9E_Q8U',
#   '7QPP_VDX',
#   '6btn_E8M_A_304',
#   '1pi3_TZD_A_530',
#   '4crg_J4X_A_1493',
#   '8QQ4_WEE',
#   '7Q6H_PHU',
#   '5kf2_COA_A_401',
#   '7U70_LW0',
#   '5SIM_JKO',
#   '7VM6_7R8',
#   '1v5g_HTL_A_1602',
#   '8CNC_6D6',
#   '1s5s_PG3_A_1',
#   '8GFF_UM9',
#   '4oxy_1TN_A_302',
#   '5m66_ADN_B_502',
#   '6lql_F0C_A_702',
#   '6Z0R_Q4H',
#   '5SD7_I0E',
#   '6ooi_PGA_D_301',
#   '1kuj_MMA_A_501',
#   '7HOC_K3J',
#   '1jw0_GUA_B_999',
#   '1w3t_3GR_C_1297',
#   '8V6Z_YIG',
#   '1pr6_XYA_A_1245',
#   '6xeb_V1P_A_411',
#   '7BC9_GQM',
#   '2b04_CHO_A_200',
#   '8SIX_A1AV4',
#   '7VLP_4WI',
#   '4d4u_FUC_A_950',
#   '2uyv_TLA_C_1275',
#   '5fli_QUE_A_301',
#   '6r0i_JNB_A_901',
#   '5fiu_Y3J_B_1299',
#   '8BOM_QTX',
#   '8TFO_MEV',
#   '1y2x_NAG_D_3144',
#   '7CQS_GJL',
#   '7BCH_SWT',
#   '6lx5_C5F_A_502',
#   '4hzf_CMP_B_301',
#   '1fs5_16G_B_2267',
#   '2dcf_ACA_A_501',
#   '4nkw_PLO_B_601',
#   '5i0d_GLC_B_1122',
#   '7DIN_MPO',
#   '6vo2_R67_B_403',
#   '4rp9_ASC_A_501',
#   '2gyw_OBI_A_952',
#   '4mol_2FG_D_802',
#   '8FBQ_XOQ',
#   '7HGB_EJQ',
#   '5abz_Z47_B_201',
#   '7FVY_KL3',
#   '4bux_F35_C_2165',
#   '8A0S_KYR',
#   '7BJJ_TVW',
#   '2zuw_NDG_C_4003',
#   '7LCU_XTA',
#   '8I63_BR8',
#   '7FVW_IWI',
#   '8FV9_80J',
#   '7P7F_ADN',
#   '6a2n_UMP_B_703',
#   '5u5g_7VD_C_302',
#   '8ZUD_A1D83',
#   '3uud_EST_A_600',
#   '5fwe_OGA_B_1359',
#   '7HGE_A1A34',
#   '1h70_CIR_A_500',
#   '7LE6_K2D',
#   '1Z95_198',
#   '8AZN_RVK',
#   '5wgr_PM7_A_711',
#   '6qqs_JCZ_B_301',
#   '8CEY_UEF',
#   '1XOQ_ROF',
#   '1e5f_PLP_B_405',
#   '1kuj_MMA_C_502',
#   '1isx_XYP_A_1461',
#   '2jig_PD2_A_1254',
#   '7LDZ_K20',
#   '7UAS_MBU',
#   '2z48_NGA_B_2003',
#   '7YQR_NCA',
#   '6tor_PMP_B_504',
#   '7Y1H_F99',
#   '6Z4N_Q7B',
#   '4i9n_1E6_F_401',
#   '7QHG_T3B',
#   '5ybp_AKG_B_302',
#   '1j3k_UMP_D_711',
#   '7BCD_SWT',
#   '7WUY_76N',
#   '3wca_FPS_C_402',
#   '7VL7_GYP',
#   '1h48_CDI_F_902',
#   '5kjw_53C_B_800',
#   '1om5_INE_B_791',
#   '4uzi_IMD_B_1456',
#   '5SHO_JIC',
#   '6fs7_E4Z_E_903',
#   '8PVS_GLA',
#   '7FCX_4I1',
#   '1J3J_CP6',
#   '7UEU_AN2',
#   '5tch_MLI_G_301',
#   '4xh4_PPI_A_504',
#   '1v3v_5OP_A_1360',
#   '5edh_5MF_C_803',
#   '7NGG_U9W',
#   '5zg2_9C0_A_902',
#   '7PL1_SFG',
#   '7FEU_ELA',
#   '4umd_CIT_A_1174',
#   '4i02_CMP_A_301',
#   '2qd4_CHD_B_928',
#   '8C5M_MTA',
#   '2w1a_TSA_D_1091',
#   '8CQH_SFG',
#   '8IXS_SIU',
#   '6a7e_9QR_A_201',
#   '1e7h_PLM_A_1007',
#   '7LDY_XUY',
#   '2nos_AGU_A_903',
#   '7N4R_0B9',
#   '5tvr_AKG_A_402',
#   '5c4i_TPP_C_402',
#   '7P1M_4IU',
#   '5j61_A3G_F_501',
#   '7PHZ_U9H',
#   '1kwc_BPY_B_401',
#   '1x2a_PDG_B_1413',
#   '7ZRN_PPV',
#   '4i9n_1E6_C_401',
#   '7OP9_06K',
#   '6ncx_ADA_B_601',
#   '7AN5_RDH',
#   '4mux_2E4_A_402',
#   '7HG3_UWS',
#   '4al9_GLA_A_1123',
#   '2ot7_OGA_A_500',
#   '8FWZ_YCE',
#   '5f79_4V7_A_4000',
#   '4jb0_ENO_A_402',
#   '3zcm_PX3_B_1216',
#   '7HG1_X0S',
#   '5i0m_UMP_B_201',
#   '7FTI_YMO',
#   '1o28_UFP_A_703',
#   '8V6W_YIB',
#   '1r4f_AD3_B_330',
#   '8BI2_QR7',
#   '8QML_41K',
#   '2qd4_CHD_B_926',
#   '4rje_PYR_D_402',
#   '2fr6_CTN_A_1001',
#   '2vag_V25_A_1482',
#   '5kcj_6RM_B_302',
#   '8BM8_WT3',
#   '8A46_L5F',
#   '7GZX_A1AK4',
#   '7VRQ_QJ1',
#   '5m5a_KSA_A_404',
#   '1sjc_SMG_D_1300',
#   '1fhv_OSB_A_789',
#   '3zp7_PRE_A_1118',
#   '1toq_AMG_E_503',
#   '1aia_PMP_B_411',
#   '2npq_BOG_A_2000',
#   '7XH6_EL0',
#   '1a9r_HPA_A_290',
#   '7TXP_0FX',
#   '7W05_GMP',
#   '4pik_MAN_A_501',
#   '7FEZ_ELA',
#   '1U4D_DBQ',
#   '4wmz_TPF_A_602',
#   '4zvv_GN0_A_405',
#   '7S98_94M',
#   '5l1u_7PF_A_401',
#   '7GCE_L4N',
#   '8AVA_OVO',
#   '1uxi_FUM_B_1311',
#   '5SAU_1IJ',
#   '4d06_NAR_E_301',
#   '2oxp_THP_A_300',
#   '3u3o_3QV_A_297',
#   '4b98_PXG_B_470',
#   '3uwb_BB2_A_154',
#   '8BSB_DAR',
#   '9BOH_A1AQW',
#   '7V0Z_OTL',
#   '1OYT_FSN',
#   '8BOC_QU6',
#   '1thc_FL9_B_130',
#   '1aiq_UMP_A_265',
#   '7USH_37T',
#   '8B5Y_P8O',
#   '8BM2_S4R',
#   '8R5T_Y4E',
#   '5xrv_F6R_A_702',
#   '5SKP_IZ6',
#   '8I2R_FRU',
#   '7X5N_5M5',
#   '5faj_DCS_D_401',
#   '7GLF_KG9',
#   '1giu_ADE_A_300',
#   '7GLA_KG9',
#   '4kux_FPS_C_705',
#   '7LE0_NF7',
#   '7F06_0TL',
#   '2wdq_CBE_G_1130',
#   '4pxd_1AL_A_502',
#   '2qim_ZEA_A_159',
#   '4itu_1HS_D_302',
#   '4nkw_PLO_C_601',
#   '8UL7_5N6',
#   '2i1v_F6P_B_720',
#   '6br1_E3Y_B_505',
#   '7RH0_59O',
#   '7VS1_82V',
#   '7FDT_6NA',
#   '5kxb_NGA_A_307',
#   '8AAU_LH0',
#   '1gxu_2HP_A_1092',
#   '8B5G_LDR',
#   '8V74_YHE',
#   '7PUV_84Z',
#   '7GLA_S1U',
#   '1pr0_NOS_A_1245',
#   '3qt8_FM0_A_328',
#   '7V16_OTL',
#   '4evq_PHB_A_406',
#   '7RXO_80E',
#   '5gwx_SAR_A_302',
#   '7S3T_QRP',
#   '4cld_JUO_B_1270',
#   '5c8w_PCG_C_302',
#   '7SEA_8XF',
#   '8R5K_A1H70',
#   '5bkd_AKG_B_502',
#   '3wsg_CIT_F_302',
#   '2c6q_IMP_A_1337',
#   '8V73_YHN',
#   '4fxr_BMP_A_301',
#   '3zr0_8OG_B_1157',
#   '1msv_PUT_B_355',
#   '7OF8_SIU',
#   '7FU9_YUB',
#   '8EWZ_X0I',
#   '8QMZ_W6O',
#   '8P7H_X3B',
#   '7T2I_E9F',
#   '3w4i_8LG_C_402',
#   '1h8p_PC_B_1110',
#   '7BJ6_TVK',
#   '5SHO_JQL',
#   '7DYT_HR3',
#   '1x29_PMG_A_413',
#   '5tch_MLI_E_301',
#   '5tzr_MLI_A_2403',
#   '2c6q_IMP_D_1337',
#   '8DKQ_SJU',
#   '4mgj_CPZ_A_502',
#   '1xid_ASC_A_389',
#   '7ROR_69X',
#   '4hez_1MZ_A_306',
#   '6krs_CIT_C_301',
#   '2z48_NGA_B_2006',
#   '5agl_CCW_A_800',
#   '8F8E_XJI',
#   '7ZIF_IWA',
#   '7U0S_KXX',
#   '8AOP_A1HZ6',
#   '4k90_MLA_A_704',
#   '7UMV_NUU',
#   '5yb7_ORN_B_603',
#   '8PTS_EIF',
#   '5m66_ADN_A_502',
#   '3vbn_TYD_C_301',
#   '5i5t_67X_A_402',
#   '7DKM_NAD',
#   '4k5u_GAL_D_301',
#   '8V6Y_YHE',
#   '6btq_E8S_A_305',
#   '5cyf_FLC_A_301',
#   '5g4r_LF1_C_1739',
#   '4f8n_GAL_A_204',
#   '5yaq_ISE_D_402',
#   '6b9p_D0J_A_1001',
#   '5aov_GLV_A_1336',
#   '8XPV_4Z5',
#   '7NGM_U9W',
#   '5SI1_JSM',
#   '3qhd_CTN_B_165',
#   '4ox5_DAL_A_307',
#   '6si4_LEK_B_402',
#   '8TE9_8X3',
#   '6qli_4LR_A_301',
#   '1jtk_THU_B_1138',
#   '7LE5_DJR',
#   '5eo8_TFU_A_402',
#   '7FVZ_IWI',
#   '2c5b_5F1_C_500',
#   '1V4S_MRK',
#   '4npm_SIN_A_301',
#   '7H0S_A1AMV',
#   '7FVW_IQH',
#   '8ZTX_A1D82',
#   '7F21_FMN',
#   '4d96_5PA_A_501',
#   '4g1x_TQU_A_410',
#   '2prg_BRL_A_1',
#   '4i9n_1E6_H_401',
#   '4gt9_UMP_A_302',
#   '5i8z_JA1_A_302',
#   '7JXX_VP7',
#   '2zyv_NPO_X_1601',
#   '3vnj_PSJ_D_301',
#   '7SDB_IHP',
#   '6pk1_3PY_A_502',
#   '2vzu_PNJ_B_1904',
#   '8FP1_XXF',
#   '1u2o_NEC_A_1001',
#   '7RGY_5BI',
#   '7FW1_IQH',
#   '5SM7_LPU',
#   '4h4c_10D_A_402',
#   '8BOI_QT1',
#   '1j3k_WRA_B_709',
#   '8PQF_9JI',
#   '8R5B_Y32',
#   '5xdt_MB3_A_404',
#   '2cxp_A5P_B_2601',
#   '4a8p_PAO_D_1340',
#   '7EBG_J0L',
#   '5ew8_5SF_B_802',
#   '4cld_JUO_C_1270',
#   '5wgw_MB5_A_715',
#   '5yb7_ORN_A_603',
#   '4cld_JUO_A_1270',
#   '5SAW_1K2',
#   '7S9H_7PP',
#   '8EX2_Q2Q',
#   '7GZV_A1AK3',
#   '8RAK_YMH',
#   '4do1_ANN_C_502',
#   '5a66_3PO_A_1000',
#   '8GF1_ZHE',
#   '6vv1_RMJ_A_501',
#   '9FLQ_A1IDD',
#   '2dm5_ODI_A_312',
#   '2wu4_HBP_A_1544',
#   '5x5d_UMP_D_401',
#   '4h9x_HL4_A_404',
#   '6ly4_TES_A_501',
#   '9JOA_UW0',
#   '2qg6_NMN_A_301',
#   '8OHU_VON',
#   '6tof_NQE_A_201',
#   '5faj_DCS_A_401',
#   '7NLV_UJE',
#   '1jyx_IPT_A_2001',
#   '7FVU_GFS',
#   '4zsy_RW2_D_502',
#   '4kux_FPS_B_405',
#   '5z9b_HX3_A_303',
#   '2v60_C17_A_1503',
#   '5SFE_IK0',
#   '5ykt_PMP_A_501',
#   '2pnz_UDP_A_250',
#   '8BSD_TBN',
#   '4i0b_CMP_A_302',
#   '6dmi_5T5_A_504',
#   '8BK0_QT1',
#   '8DX8_T27',
#   '1e8g_FCR_B_601',
#   '7ZGZ_IVG',
#   '7RKR_L49',
#   '7SZF_D82',
#   '5SAU_1IM',
#   '4lz7_1YW_C_804',
#   '6urx_JMG_A_316',
#   '7HG8_A1A34',
#   '1g8z_GAL_H_104',
#   '1l5o_NCN_A_991',
#   '6gck_EUB_D_302',
#   '1KZK_JE2',
#   '1z3n_3NA_A_320',
#   '5jtt_6MY_A_902',
#   '4n94_2HO_A_401',
#   '8V72_YJQ',
#   '3qss_MTG_B_405',
#   '8BM2_QQC',
#   '1jf0_CZH_A_197',
#   '6png_OSG_A_803',
#   '7FDU_OCA',
#   '4n9v_AZA_A_403',
#   '1y8j_STS_A_900',
#   '6nga_KL7_A_803',
#   '4ud9_FQI_H_1257',
#   '4z2w_AKG_A_401',
#   '7V15_OTL',
#   '8TQN_EPE',
#   '7SFO_98L',
#   '1w55_C_A_1372',
#   '7SIU_9ID',
#   '8IQT_SV0',
#   '3vnj_PSJ_A_301',
#   '5SFE_IYW',
#   '8A46_VCQ',
#   '4al9_GLA_E_1123',
#   '8V6W_YIG',
#   '6n9r_OHN_A_303',
#   '8RTW_TES',
#   '8EFN_4BW',
#   '4xpq_FUL_A_1004',
#   '6qor_JBK_A_301',
#   '9BCA_A1APS',
#   '2isf_PAC_A_317',
#   '5SFE_KHU',
#   '6jz4_EVA_A_701',
#   '4ptx_BGC_A_501',
#   '4mog_G3F_A_802',
#   '5vv0_9OM_A_803',
#   '7GAW_R8X',
#   '7Z1Q_NIO',
#   '9BFB_A1AN9',
#   '5unx_8F1_A_803',
#   '8E0T_52L',
#   '5eo8_TFU_A_405',
#   '5unt_8J1_A_803',
#   '2as1_TP5_A_500',
#   '7DQL_4CL',
#   '1cq1_BGC_A_455',
#   '5lqs_NTM_A_302',
#   '4e7v_CRS_3_101',
#   '1h1m_KMP_C_1358',
#   '8GEV_ZE2',
#   '6jme_ORO_A_402',
#   '5l9v_OGA_A_502',
#   '7GL3_KG9',
#   '7FVZ_GFS',
#   '7B2U_R4X',
#   '7F10_0ER',
#   '5irw_D9P_A_202',
#   '8T2H_XIR',
#   '8J5E_TV0',
#   '8CB3_MPO',
#   '7LDZ_DJR',
#   '2r4t_250_A_503',
#   '6ooi_PGA_B_301',
#   '1ca7_ENO_C_701',
#   '6rgg_K3Q_A_403',
#   '1LRH_NLA',
#   '5wgw_MB5_A_714',
#   '6lx5_C5F_A_503',
#   '2j5b_TYE_B_1338',
#   '7FRX_O88',
#   '6krs_CIT_H_301',
#   '5n63_8OW_A_401',
#   '2qab_EI1_A_1',
#   '7H01_A1AK7',
#   '4d06_NAR_F_301',
#   '7HG1_A1A34',
#   '7GZW_A1ALR',
#   '7R7K_25J',
#   '1h5r_THM_C_1293',
#   '7ZDY_IVG',
#   '5unr_8EV_B_803',
#   '9GR6_SFG',
#   '2qx4_ML1_B_233',
#   '1m9j_CLW_B_907',
#   '8FX0_IMU',
#   '1n3o_GYP_B_1101',
#   '1pr6_XYA_C_1247',
#   '7VYJ_CA0',
#   '1aua_BOG_A_1',
#   '7FUB_YOB',
#   '7GZZ_A1ALQ',
#   '8RDT_A1HZ6',
#   '3qxx_8AC_A_221',
#   '7HGE_EJQ',
#   '5dnx_5LD_B_201',
#   '4p8c_Y22_A_502',
#   '1s83_4HA_A_5',
#   '8V6Y_YIG',
#   '7B9D_EJW',
#   '7V17_OR0',
#   '8J5F_TQR',
#   '6s37_SAL_A_601',
#   '2giq_NN2_A_1001',
#   '7R7E_AMP',
#   '5vyr_B62_B_301',
#   '5i93_69O_A_202',
#   '7VS1_37T',
#   '2ex1_C5P_A_1427',
#   '7R7K_A1IJ8',
#   '6auq_BYJ_A_803',
#   '5iav_MLI_B_302',
#   '7H0S_A1AMD',
#   '5ud3_P6F_B_404',
#   '2o7d_DHC_A_701',
#   '8U96_ADP',
#   '5gwt_SIN_D_301',
#   '4i6w_1CO_B_1001',
#   '7BNH_BEZ',
#   '4evi_C9M_A_402',
#   '7FDX_OCA',
#   '5thu_B3N_A_404',
#   '2wch_B7M_A_1145',
#   '7PHZ_S1U',
#   '2eup_LG4_A_400',
#   '8V70_YHS',
#   '3zzv_FUC_B_401',
#   '2o7d_DHC_E_701',
#   '5S9U_FAD',
#   '4hey_4MZ_A_303',
#   '7GBY_L5I',
#   '4r2n_PLP_B_401',
#   '4n36_2F8_D_401',
#   '8CV9_HYO',
#   '7NU0_DCL',
#   '6yaw_P9H_B_502',
#   '5gwt_SIN_C_301',
#   '8R2B_XN0',
#   '8A8Z_LDL',
#   '3vnm_SDD_D_301',
#   '7LE0_K2D',
#   '5lwy_OLB_A_402',
#   '7CD9_FVR',
#   '1pke_2FD_A_446',
#   '1zmt_RNO_D_1004',
#   '1uux_PPI_A_1165',
#   '4clr_FDB_C_1270',
#   '6T88_MWQ',
#   '5yb7_ORN_D_603',
#   '7LDZ_K2E',
#   '7GZX_A1AK3',
#   '6b83_6NA_B_201',
#   '2vzu_PNJ_A_1901',
#   '8GF0_UL6',
#   '5ybp_8SX_B_303',
#   '3rop_NCA_B_302',
#   '2z20_PLP_A_701',
#   '6lx5_C5F_B_501',
#   '2qxf_TMP_A_3000',
#   '2qui_LTN_B_478',
#   ...],
#  'embeddings': tensor([[ 0.2419,  0.0170, -0.0845,  ...,  0.1346, -0.2697, -0.1792],
#          [ 0.1278, -0.1483,  0.0288,  ...,  0.1754, -0.0561, -0.2009],
#          [ 0.0511,  0.0937, -0.1299,  ...,  0.2157, -0.1796, -0.0384],
#          ...,
#          [ 0.1162, -0.0397,  0.0260,  ...,  0.1379, -0.0454, -0.2004],
#          [ 0.0896, -0.0512, -0.1604,  ...,  0.2086, -0.1272, -0.1015],
#          [-0.0694, -0.0180, -0.0764,  ...,  0.1447, -0.0185, -0.1458]])}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
graph['embeddings'].shape
# Out:
# torch.Size([5623, 384])
